# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiarochinhauab/MiniProj2/blob/main/DeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Imports

# %%
#imports
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision import transforms as T
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

#for the zip files
import zipfile

# %% [markdown]
# ## 1.1 Import the images

# %%
#import json config in the kaggle profile for api
# for get the dataset, you need to access the kaggle account and get the api
# after that, you do the upload the json that you save when you get the api
#profile -> api -> token -> upload the json

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-61f71a8e-dba6-4e73-b965-1e32b6e22098" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61f71a8e-dba6-4e73-b965-1e32b6e22098">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# create a new directory for the json file
# we need that fot load the dataset
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

#import all the images
# !kaggle datasets download -d balraj98/deepglobe-road-extraction-dataset
# Out:
# ...
# 100% 3.79G/3.79G [00:52<00:00, 56.3MB/s]
# 100% 3.79G/3.79G [00:52<00:00, 78.3MB/s]

# %%
#unzip all the files
zip_ref = zipfile.ZipFile('deepglobe-road-extraction-dataset.zip', 'r')
zip_ref.extractall('files')
zip_ref.close()

# %% [markdown]
# # 2. Setup Model

# %%
mask = Image.open('/content/files/train/100034_mask.png')
img = Image.open('/content/files/train/100034_sat.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
np.unique(mask)
# Out:
# array([  0, 255], dtype=uint8)
